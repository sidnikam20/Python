# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/titanic_dataset.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.drop(0,axis=0,inplace=True)

# %% [markdown]
# axis=o -> drop row
# axis=1 -> drop column
# 0= index no
# inplace=true ->do drop in same database

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %%
data.drop([1,2,3],axis=0,inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 4      0  373450   8.0500   NaN        S
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S

# %%
data.drop([4,5],axis=0,inplace=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 4      0  373450   8.0500   NaN        S
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S

# %% [markdown]
# we still able to see 4,5 as we write inplace=false

# %% [markdown]
# if you want to do that changes permenant in data assign that o/p to data

# %%
data=data.drop([4,5],axis=0,inplace=False)

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch   Ticket     Fare Cabin Embarked
# 6       0    17463  51.8625   E46        S
# 7       1   349909  21.0750   NaN        S
# 8       2   347742  11.1333   NaN        S
# 9       0   237736  30.0708   NaN        C
# 10      1  PP 9549  16.7000    G6        S

# %%
data.drop([4,5],axis=0,inplace=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-3b8faf658d3c> in <cell line: 0>()
# ----> 1 data.drop([4,5],axis=0,inplace=False)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %% [markdown]
# to suspend this error we use error=ignore

# %%
data.drop([4,5],axis=0,inplace=False,errors='ignore')
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# default value of axis is 0(row wise)
# and inplace is False

# %%
data.drop([6,7])
# Out:
#      PassengerId  Survived  Pclass  \
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch   Ticket     Fare Cabin Embarked
# 6       0    17463  51.8625   E46        S
# 7       1   349909  21.0750   NaN        S
# 8       2   347742  11.1333   NaN        S
# 9       0   237736  30.0708   NaN        C
# 10      1  PP 9549  16.7000    G6        S

# %% [markdown]
# acess row:

# %%
data.index[0]
# Out:
# 6

# %%
data=data.drop(data.index[0])

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch   Ticket     Fare Cabin Embarked
# 7       1   349909  21.0750   NaN        S
# 8       2   347742  11.1333   NaN        S
# 9       0   237736  30.0708   NaN        C
# 10      1  PP 9549  16.7000    G6        S
# 11      0   113783  26.5500  C103        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data=data.drop(data.index[-1])

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 885  female  39.0      0      5      382652  29.125   NaN        Q
# 886    male  27.0      0      0      211536  13.000   NaN        S
# 887  female  19.0      0      0      112053  30.000   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.450   NaN        S
# 889    male  26.0      0      0      111369  30.000  C148        C

# %%
data.index[[1,3]]
# Out:
# Index([8, 10], dtype='int64')

# %% [markdown]
# delete by Range:

# %%
data.index[0:5]
# Out:
# RangeIndex(start=7, stop=12, step=1)

# %%
data.drop(data.index[0:5],inplace=True)

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 15           16         1       2      Hewlett, Mrs. (Mary D Kingcome)
# 16           17         0       3                  Rice, Master. Eugene
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 12    male  20.0      0      0  A/5. 2151   8.0500   NaN        S
# 13    male  39.0      1      5     347082  31.2750   NaN        S
# 14  female  14.0      0      0     350406   7.8542   NaN        S
# 15  female  55.0      0      0     248706  16.0000   NaN        S
# 16    male   2.0      4      1     382652  29.1250   NaN        Q

# %% [markdown]
# Get the row and drop it:

# %%
data.loc[data["Name"]=="Vestrom, Miss. Hulda Amanda Adolfina"]
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#        Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 14  female  14.0      0      0  350406  7.8542   NaN        S

# %%
data=data.loc[data["Name"]!="Vestrom, Miss. Hulda Amanda Adolfina"]

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 12           13         0       3    Saundercock, Mr. William Henry    male
# 13           14         0       3       Andersson, Mr. Anders Johan    male
# 15           16         1       2  Hewlett, Mrs. (Mary D Kingcome)   female
# 16           17         0       3              Rice, Master. Eugene    male
# 17           18         1       2      Williams, Mr. Charles Eugene    male
#
#      Age  SibSp  Parch     Ticket    Fare Cabin Embarked
# 12  20.0      0      0  A/5. 2151   8.050   NaN        S
# 13  39.0      1      5     347082  31.275   NaN        S
# 15  55.0      0      0     248706  16.000   NaN        S
# 16   2.0      4      1     382652  29.125   NaN        Q
# 17   NaN      0      0     244373  13.000   NaN        S

# %% [markdown]
# else you can use it column wise also

# %% [markdown]
# Column wise:

# %%
df=data.copy()

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 12           13         0       3    Saundercock, Mr. William Henry    male
# 13           14         0       3       Andersson, Mr. Anders Johan    male
# 15           16         1       2  Hewlett, Mrs. (Mary D Kingcome)   female
# 16           17         0       3              Rice, Master. Eugene    male
# 17           18         1       2      Williams, Mr. Charles Eugene    male
#
#      Age  SibSp  Parch     Ticket    Fare Cabin Embarked
# 12  20.0      0      0  A/5. 2151   8.050   NaN        S
# 13  39.0      1      5     347082  31.275   NaN        S
# 15  55.0      0      0     248706  16.000   NaN        S
# 16   2.0      4      1     382652  29.125   NaN        Q
# 17   NaN      0      0     244373  13.000   NaN        S

# %%
df.drop("Survived",axis=1,inplace=True)

# %%
df.head()
# Out:
#     PassengerId  Pclass                              Name     Sex   Age  \
# 12           13       3    Saundercock, Mr. William Henry    male  20.0
# 13           14       3       Andersson, Mr. Anders Johan    male  39.0
# 15           16       2  Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 16           17       3              Rice, Master. Eugene    male   2.0
# 17           18       2      Williams, Mr. Charles Eugene    male   NaN
#
#     SibSp  Parch     Ticket    Fare Cabin Embarked
# 12      0      0  A/5. 2151   8.050   NaN        S
# 13      1      5     347082  31.275   NaN        S
# 15      0      0     248706  16.000   NaN        S
# 16      4      1     382652  29.125   NaN        Q
# 17      0      0     244373  13.000   NaN        S

# %%
df.drop(["PassengerId","Pclass"],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                 Name     Sex   Age  SibSp  Parch     Ticket  \
# 12    Saundercock, Mr. William Henry    male  20.0      0      0  A/5. 2151
# 13       Andersson, Mr. Anders Johan    male  39.0      1      5     347082
# 15  Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0     248706
# 16              Rice, Master. Eugene    male   2.0      4      1     382652
# 17      Williams, Mr. Charles Eugene    male   NaN      0      0     244373
#
#       Fare Cabin Embarked
# 12   8.050   NaN        S
# 13  31.275   NaN        S
# 15  16.000   NaN        S
# 16  29.125   NaN        Q
# 17  13.000   NaN        S

# %%
df=df.drop(columns='Sex')

# %%
df.head()
# Out:
#      Age  SibSp  Parch     Ticket    Fare Cabin Embarked
# 12  20.0      0      0  A/5. 2151   8.050   NaN        S
# 13  39.0      1      5     347082  31.275   NaN        S
# 15  55.0      0      0     248706  16.000   NaN        S
# 16   2.0      4      1     382652  29.125   NaN        Q
# 17   NaN      0      0     244373  13.000   NaN        S

# %%
df.drop(columns=['Age','Fare'],inplace=True)

# %%
df.head()
# Out:
#     SibSp  Parch     Ticket Cabin Embarked
# 12      0      0  A/5. 2151   NaN        S
# 13      1      5     347082   NaN        S
# 15      0      0     248706   NaN        S
# 16      4      1     382652   NaN        Q
# 17      0      0     244373   NaN        S

# %%
df.columns
# Out:
# Index(['SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df.columns[1]
# Out:
# 'Parch'

# %%
df=df.drop(df.columns[1],axis=1)

# %%
df.head()
# Out:
#     SibSp     Ticket Cabin Embarked
# 12      0  A/5. 2151   NaN        S
# 13      1     347082   NaN        S
# 15      0     248706   NaN        S
# 16      4     382652   NaN        Q
# 17      0     244373   NaN        S

# %%
df.columns[[1,2]]
# Out:
# Index(['Ticket', 'Cabin'], dtype='object')

# %%
df.iloc[:,1:3]
# Out:
#          Ticket Cabin
# 12    A/5. 2151   NaN
# 13       347082   NaN
# 15       248706   NaN
# 16       382652   NaN
# 17       244373   NaN
# ..          ...   ...
# 885      382652   NaN
# 886      211536   NaN
# 887      112053   B42
# 888  W./C. 6607   NaN
# 889      111369  C148
#
# [877 rows x 2 columns]

# %% [markdown]
# : -> is for rows

# %%
df=df.drop(df.iloc[:,1:3],axis=1)

# %%
df.head()
# Out:
#     SibSp Embarked
# 12      0        S
# 13      1        S
# 15      0        S
# 16      4        Q
# 17      0        S

# %%
df=data.copy()

# %%
df.drop(df.loc[:,'Name':'Ticket'].columns,axis=1,inplace=True)

# %%
df.head()
# Out:
#     Pclass    Fare Cabin Embarked
# 12       3   8.050   NaN        S
# 13       3  31.275   NaN        S
# 15       2  16.000   NaN        S
# 16       3  29.125   NaN        Q
# 17       2  13.000   NaN        S

# %%
lisCols=["Pclass","Fare","Embarked"]
df=df.drop(lisCols,axis=1)

# %%
df.head()
# Out:
#    Cabin
# 12   NaN
# 13   NaN
# 15   NaN
# 16   NaN
# 17   NaN

# %% [markdown]
# Rename column Name:

# %%
df=data.copy()

# %%
df.head()
# Out:
#     Pclass                              Name     Sex   Age  SibSp  Parch  \
# 12       3    Saundercock, Mr. William Henry    male  20.0      0      0
# 13       3       Andersson, Mr. Anders Johan    male  39.0      1      5
# 15       2  Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 16       3              Rice, Master. Eugene    male   2.0      4      1
# 17       2      Williams, Mr. Charles Eugene    male   NaN      0      0
#
#        Ticket    Fare Cabin Embarked
# 12  A/5. 2151   8.050   NaN        S
# 13     347082  31.275   NaN        S
# 15     248706  16.000   NaN        S
# 16     382652  29.125   NaN        Q
# 17     244373  13.000   NaN        S

# %%
df.rename(columns={"Fare":"total_Fare"},inplace=True)

# %%
df.head()
# Out:
#     Pclass                              Name     Sex   Age  SibSp  Parch  \
# 12       3    Saundercock, Mr. William Henry    male  20.0      0      0
# 13       3       Andersson, Mr. Anders Johan    male  39.0      1      5
# 15       2  Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 16       3              Rice, Master. Eugene    male   2.0      4      1
# 17       2      Williams, Mr. Charles Eugene    male   NaN      0      0
#
#        Ticket  total_Fare Cabin Embarked
# 12  A/5. 2151       8.050   NaN        S
# 13     347082      31.275   NaN        S
# 15     248706      16.000   NaN        S
# 16     382652      29.125   NaN        Q
# 17     244373      13.000   NaN        S

# %%
df.rename(columns={'Name':'Names','Ticket':'Ticket_no.'},inplace=True)

# %%
df.head()
# Out:
#     Pclass                             Names     Sex   Age  SibSp  Parch  \
# 12       3    Saundercock, Mr. William Henry    male  20.0      0      0
# 13       3       Andersson, Mr. Anders Johan    male  39.0      1      5
# 15       2  Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 16       3              Rice, Master. Eugene    male   2.0      4      1
# 17       2      Williams, Mr. Charles Eugene    male   NaN      0      0
#
#    Ticket_no.  total_Fare Cabin Embarked
# 12  A/5. 2151       8.050   NaN        S
# 13     347082      31.275   NaN        S
# 15     248706      16.000   NaN        S
# 16     382652      29.125   NaN        Q
# 17     244373      13.000   NaN        S
